# %% [markdown]
# <a href="https://colab.research.google.com/github/AGON002/python-assignment/blob/main/EDA_Assg_NYC_Taxi_Starter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **New York City Yellow Taxi Data**

# %% [markdown]
# ## Objective
# In this case study you will be learning exploratory data analysis (EDA) with the help of a dataset on yellow taxi rides in New York City. This will enable you to understand why EDA is an important step in the process of data science and machine learning.

# %% [markdown]
# ## **Problem Statement**
# As an analyst at an upcoming taxi operation in NYC, you are tasked to use the 2023 taxi trip data to uncover insights that could help optimise taxi operations. The goal is to analyse patterns in the data that can inform strategic decisions to improve service efficiency, maximise revenue, and enhance passenger experience.

# %% [markdown]
# ## Tasks
# You need to perform the following steps for successfully completing this assignment:
# 1. Data Loading
# 2. Data Cleaning
# 3. Exploratory Analysis: Bivariate and Multivariate
# 4. Creating Visualisations to Support the Analysis
# 5. Deriving Insights and Stating Conclusions

# %% [markdown]
# ---

# %% [markdown]
# **NOTE:** The marks given along with headings and sub-headings are cumulative marks for those particular headings/sub-headings.<br>
#
# The actual marks for each task are specified within the tasks themselves.
#
# For example, marks given with heading *2* or sub-heading *2.1* are the cumulative marks, for your reference only. <br>
#
# The marks you will receive for completing tasks are given with the tasks.
#
# Suppose the marks for two tasks are: 3 marks for 2.1.1 and 2 marks for 3.2.2, or
# * 2.1.1 [3 marks]
# * 3.2.2 [2 marks]
#
# then, you will earn 3 marks for completing task 2.1.1 and 2 marks for completing task 3.2.2.

# %% [markdown]
# ---

# %% [markdown]
# ## Data Understanding
# The yellow taxi trip records include fields capturing pick-up and drop-off dates/times, pick-up and drop-off locations, trip distances, itemized fares, rate types, payment types, and driver-reported passenger counts.
#
# The data is stored in Parquet format (*.parquet*). The dataset is from 2009 to 2024. However, for this assignment, we will only be using the data from 2023.
#
# The data for each month is present in a different parquet file. You will get twelve files for each of the months in 2023.
#
# The data was collected and provided to the NYC Taxi and Limousine Commission (TLC) by technology providers like vendors and taxi hailing apps. <br>
#
# You can find the link to the TLC trip records page here: https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page

# %% [markdown]
# ###  Data Description
# You can find the data description here: [Data Dictionary](https://www.nyc.gov/assets/tlc/downloads/pdf/data_dictionary_trip_records_yellow.pdf)

# %% [markdown]
# **Trip Records**
#
#
#
# |Field Name       |description |
# |:----------------|:-----------|
# | VendorID | A code indicating the TPEP provider that provided the record. <br> 1= Creative Mobile Technologies, LLC; <br> 2= VeriFone Inc. |
# | tpep_pickup_datetime | The date and time when the meter was engaged.  |
# | tpep_dropoff_datetime | The date and time when the meter was disengaged.   |
# | Passenger_count | The number of passengers in the vehicle. <br> This is a driver-entered value. |
# | Trip_distance | The elapsed trip distance in miles reported by the taximeter. |
# | PULocationID | TLC Taxi Zone in which the taximeter was engaged |
# | DOLocationID | TLC Taxi Zone in which the taximeter was disengaged |
# |RateCodeID |The final rate code in effect at the end of the trip.<br> 1 = Standard rate <br> 2 = JFK <br> 3 = Newark <br>4 = Nassau or Westchester <br>5 = Negotiated fare <br>6 = Group ride |
# |Store_and_fwd_flag |This flag indicates whether the trip record was held in vehicle memory before sending to the vendor, aka “store and forward,” because the vehicle did not have a connection to the server.  <br>Y= store and forward trip <br>N= not a store and forward trip |
# |Payment_type| A numeric code signifying how the passenger paid for the trip. <br> 1 = Credit card <br>2 = Cash <br>3 = No charge <br>4 = Dispute <br>5 = Unknown <br>6 = Voided trip |
# |Fare_amount| The time-and-distance fare calculated by the meter. <br>Extra Miscellaneous extras and surcharges.  Currently, this only includes the 0.50 and 1 USD rush hour and overnight charges. |
# |MTA_tax |0.50 USD MTA tax that is automatically triggered based on the metered rate in use. |
# |Improvement_surcharge | 0.30 USD improvement surcharge assessed trips at the flag drop. The improvement surcharge began being levied in 2015. |
# |Tip_amount |Tip amount – This field is automatically populated for credit card tips. Cash tips are not included. |
# | Tolls_amount | Total amount of all tolls paid in trip.  |
# | total_amount | The total amount charged to passengers. Does not include cash tips. |
# |Congestion_Surcharge |Total amount collected in trip for NYS congestion surcharge. |
# | Airport_fee | 1.25 USD for pick up only at LaGuardia and John F. Kennedy Airports|
#
# Although the amounts of extra charges and taxes applied are specified in the data dictionary, you will see that some cases have different values of these charges in the actual data.

# %% [markdown]
# **Taxi Zones**
#
# Each of the trip records contains a field corresponding to the location of the pickup or drop-off of the trip, populated by numbers ranging from 1-263.
#
# These numbers correspond to taxi zones, which may be downloaded as a table or map/shapefile and matched to the trip records using a join.
#
# This is covered in more detail in later sections.

# %% [markdown]
# ---

# %%
# numpy version: 1.26.4
# pandas version: 2.2.2
# matplotlib version: 3.10.0
# seaborn version: 0.13.2
# %pip install numpy==1.26.4 pandas==2.2.2 seaborn==0.13.2 matplotlib==3.10.0
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## **1** Data Preparation
#
# <font color = red>[5 marks]</font> <br>

# %% [markdown]
# ### Import Libraries

# %%
# Import warnings
import warnings

# %%
# Import the libraries you will be using for analysis

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Recommended versions
# numpy version: 1.26.4
# pandas version: 2.2.2
# matplotlib version: 3.10.0
# seaborn version: 0.13.2

# Check versions
print("numpy version:", np.__version__)
print("pandas version:", pd.__version__)
print("matplotlib version:", plt.matplotlib.__version__)
print("seaborn version:", sns.__version__)
# Out:
# numpy version: 2.0.2
# pandas version: 2.2.2
# matplotlib version: 3.10.0
# seaborn version: 0.13.2

# %% [markdown]
# ### **1.1** Load the dataset
# <font color = red>[5 marks]</font> <br>

# %% [markdown]
# You will see twelve files, one for each month.
#
# To read parquet files with Pandas, you have to follow a similar syntax as that for CSV files.
#
# `df = pd.read_parquet('file.parquet')`

# %%
# Try loading one file

# from google.colab import drive
# drive.mount('/content/drive')

df= pd.read_parquet('/content/drive/MyDrive/data_files/yellow_tripdata_2023-01.parquet')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3066766 entries, 0 to 3066765
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int64
#  1   tpep_pickup_datetime   datetime64[us]
#  2   tpep_dropoff_datetime  datetime64[us]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int64
#  8   DOLocationID           int64
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  airport_fee            float64
# dtypes: datetime64[us](2), float64(12), int64(4), object(1)
# ...

# %% [markdown]
# How many rows are there? Do you think handling such a large number of rows is computationally feasible when we have to combine the data for all twelve months into one?
#
# To handle this, we need to sample a fraction of data from each of the files. How to go about that? Think of a way to select only some portion of the data from each month's file that accurately represents the trends.

# %% [markdown]
# #### Sampling the Data
# > One way is to take a small percentage of entries for pickup in every hour of a date. So, for all the days in a month, we can iterate through the hours and select 5% values randomly from those. Use `tpep_pickup_datetime` for this. Separate date and hour from the datetime values and then for each date, select some fraction of trips for each of the 24 hours.
#
# To sample data, you can use the `sample()` method. Follow this syntax:
#
# ```Python
# # sampled_data is an empty DF to keep appending sampled data of each hour
# # hour_data is the DF of entries for an hour 'X' on a date 'Y'
#
# sample = hour_data.sample(frac = 0.05, random_state = 42)
# # sample 0.05 of the hour_data
# # random_state is just a seed for sampling, you can define it yourself
#
# sampled_data = pd.concat([sampled_data, sample]) # adding data for this hour to the DF
# ```
#
# This *sampled_data* will contain 5% values selected at random from each hour.
#
# Note that the code given above is only the part that will be used for sampling and not the complete code required for sampling and combining the data files.
#
# Keep in mind that you sample by date AND hour, not just hour. (Why?)

# %% [markdown]
# ---

# %% [markdown]
# **1.1.1** <font color = red>[5 marks]</font> <br>
# Figure out how to sample and combine the files.

# %% [markdown]
# **Note:** It is not mandatory to use the method specified above. While sampling, you only need to make sure that your sampled data represents the overall data of all the months accurately.

# %%
# Sample the data
# It is recommmended to not load all the files at once to avoid memory overload

# %%
# Take a small percentage of entries from each hour of every date.
# Iterating through the monthly data:
#   read a month file -> day -> hour: append sampled data -> move to next hour -> move to next day after 24 hours -> move to next month file
# Create a single dataframe for the year combining all the monthly data

# Select the folder having data files
import os

# Select the folder having data files
os.chdir('/content/drive/MyDrive/data_files')

# Create a list of all the twelve files to read
file_list = os.listdir()

# initialise an empty dataframe
df = pd.DataFrame()
sample_fraction = 0.007

# iterate through the list of files and sample one by one:
for file_name in file_list:
    try:
        # file path for the current file
        file_path = os.path.join(os.getcwd(), file_name)

        # Reading the current file
        df_each = pd.read_parquet(file_path)
        df_each['date'] = df_each['tpep_pickup_datetime'].dt.date
        df_each['hour'] = df_each['tpep_pickup_datetime'].dt.hour

        # We will store the sampled data for the current date in this df by appending the sampled data from each hour to this
        # After completing iteration through each date, we will append this data to the final dataframe.
        sampled_data = pd.DataFrame()

        sampled = (
          df_each.groupby(['date', 'hour'], group_keys=False)
          .apply(lambda x: x.sample(frac=sample_fraction, random_state=42))
        )

        df = pd.concat([df, sampled])
    except Exception as e:
        print(f"Error reading file {file_name}: {e}")
# Out:
# <ipython-input-12-c64d31029aa7>:36: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.sample(frac=sample_fraction, random_state=42))
# <ipython-input-12-c64d31029aa7>:36: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.sample(frac=sample_fraction, random_state=42))
# ...

# %% [markdown]
# After combining the data files into one DataFrame, convert the new DataFrame to a CSV or parquet file and store it to use directly.
#
# Ideally, you can try keeping the total entries to around 250,000 to 300,000.

# %%
# Store the df in csv/parquet
# df.to_parquet('')
df.to_csv('Taxi_data.csv')

# %% [markdown]
# ## **2** Data Cleaning
# <font color = red>[30 marks]</font> <br>

# %% [markdown]
# Now we can load the new data directly.

# %%
# Load the new data file

df= pd.read_csv('Taxi_data.csv')

# %%
# df.head()
df.head()
# Out:
#    Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0        1164         2  2023-01-01 00:10:30   2023-01-01 00:11:49
# 1        1868         2  2023-01-01 00:49:02   2023-01-01 00:55:15
# 2        3106         1  2023-01-01 00:47:17   2023-01-01 01:07:01
# 3         808         2  2023-01-01 00:06:02   2023-01-01 00:31:38
# 4         169         2  2023-01-01 00:02:19   2023-01-01 00:30:49
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0              1.0           0.49         1.0                  N
# 1              1.0           0.75         1.0                  N
# 2              2.0           2.90         1.0                  N
# 3              1.0           2.50         1.0                  N
# 4              1.0          20.37         2.0                  N
#
#    PULocationID  DOLocationID  ...  mta_tax  tip_amount  tolls_amount  \
# 0           239           238  ...      0.5        1.88          0.00
# ...

# %%
# df.info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268150 entries, 0 to 268149
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             268150 non-null  int64
#  1   VendorID               268150 non-null  int64
#  2   tpep_pickup_datetime   268150 non-null  object
#  3   tpep_dropoff_datetime  268150 non-null  object
#  4   passenger_count        259263 non-null  float64
#  5   trip_distance          268150 non-null  float64
#  6   RatecodeID             259263 non-null  float64
#  7   store_and_fwd_flag     259263 non-null  object
#  8   PULocationID           268150 non-null  int64
#  9   DOLocationID           268150 non-null  int64
#  10  payment_type           268150 non-null  int64
#  11  fare_amount            268150 non-null  float64
#  12  extra                  268150 non-null  float64
#  13  mta_tax                268150 non-null  float64
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0       VendorID  passenger_count  trip_distance  \
# count  2.681500e+05  268150.000000    259263.000000  268150.000000
# mean   1.604426e+06       1.736804         1.371152       4.349966
# std    9.373572e+05       0.444583         0.892247     266.246479
# min    1.400000e+01       1.000000         0.000000       0.000000
# 25%    7.971672e+05       1.000000         1.000000       1.040000
# 50%    1.594866e+06       2.000000         1.000000       1.780000
# 75%    2.391461e+06       2.000000         1.000000       3.400000
# max    3.522222e+06       6.000000         8.000000  116439.710000
#
#           RatecodeID   PULocationID   DOLocationID   payment_type  \
# count  259263.000000  268150.000000  268150.000000  268150.000000
# mean        1.630090     165.026459     163.957505       1.186705
# std         7.353466      64.086976      69.831952       0.556279
# min         1.000000       1.000000       1.000000       0.000000
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                    0
# VendorID                      0
# tpep_pickup_datetime          0
# tpep_dropoff_datetime         0
# passenger_count            8887
# trip_distance                 0
# RatecodeID                 8887
# store_and_fwd_flag         8887
# PULocationID                  0
# DOLocationID                  0
# payment_type                  0
# fare_amount                   0
# extra                         0
# mta_tax                       0
# tip_amount                    0
# tolls_amount                  0
# improvement_surcharge         0
# total_amount                  0
# congestion_surcharge       8887
# airport_fee              247175
# date                          0
# hour                          0
# Airport_fee               29862
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#         Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0             1164         2  2023-01-01 00:10:30   2023-01-01 00:11:49
# 1             1868         2  2023-01-01 00:49:02   2023-01-01 00:55:15
# 2             3106         1  2023-01-01 00:47:17   2023-01-01 01:07:01
# 3              808         2  2023-01-01 00:06:02   2023-01-01 00:31:38
# 4              169         2  2023-01-01 00:02:19   2023-01-01 00:30:49
# ...            ...       ...                  ...                   ...
# 268145     3202993         2  2023-11-30 23:34:08   2023-11-30 23:45:41
# 268146     3202493         2  2023-11-30 23:28:24   2023-11-30 23:39:51
# 268147     3205476         2  2023-11-30 23:14:41   2023-11-30 23:33:52
# 268148     3201592         2  2023-11-30 23:02:11   2023-11-30 23:08:23
# 268149     3202362         2  2023-11-30 23:28:13   2023-11-30 23:31:27
#
#         passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# ...

# %% [markdown]
# #### **2.1** Fixing Columns
# <font color = red>[10 marks]</font> <br>
#
# Fix/drop any columns as you seem necessary in the below sections

# %% [markdown]
# **2.1.1** <font color = red>[2 marks]</font> <br>
#
# Fix the index and drop unnecessary columns

# %%
# Fix the index and drop any columns that are not needed
df.reset_index(drop=True, inplace=True)
df.drop(columns=['Unnamed: 0'], inplace=True)
df.isnull().sum()
# Out:
# VendorID                      0
# tpep_pickup_datetime          0
# tpep_dropoff_datetime         0
# passenger_count            8887
# trip_distance                 0
# RatecodeID                 8887
# store_and_fwd_flag         8887
# PULocationID                  0
# DOLocationID                  0
# payment_type                  0
# fare_amount                   0
# extra                         0
# mta_tax                       0
# tip_amount                    0
# tolls_amount                  0
# improvement_surcharge         0
# total_amount                  0
# congestion_surcharge       8887
# airport_fee              247175
# date                          0
# hour                          0
# Airport_fee               29862
# dtype: int64

# %% [markdown]
# **2.1.2** <font color = red>[3 marks]</font> <br>
# There are two airport fee columns. This is possibly an error in naming columns. Let's see whether these can be combined into a single column.

# %%
# Combine the two airport fee columns
df['Airport_fee'].fillna(df['airport_fee'], inplace=True)
df.drop(columns =['airport_fee'], inplace=True)
# Out:
# <ipython-input-21-49f25ac9a824>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Airport_fee'].fillna(df['airport_fee'], inplace=True)

# %% [markdown]
# **2.1.3** <font color = red>[5 marks]</font> <br>
# Fix columns with negative (monetary) values

# %%
# check where values of fare amount are negative
df[df['fare_amount'] < 0]
# Out:
#         VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 84             2  2023-01-01 02:29:07   2023-01-01 02:29:24              1.0
# 171            2  2023-01-01 06:36:37   2023-01-01 06:44:17              1.0
# 204            2  2023-01-01 10:15:22   2023-01-01 10:15:30              1.0
# 272            2  2023-01-01 13:15:52   2023-01-01 13:28:52              1.0
# 570            2  2023-01-02 07:11:35   2023-01-02 07:11:43              1.0
# ...          ...                  ...                   ...              ...
# 267696         2  2023-11-30 15:02:21   2023-11-30 15:05:44              1.0
# 267746         2  2023-11-30 16:04:13   2023-11-30 16:06:06              1.0
# 267780         2  2023-11-30 17:44:21   2023-11-30 17:44:40              1.0
# 267792         2  2023-11-30 17:29:21   2023-11-30 17:29:39              1.0
# 267958         2  2023-11-30 20:10:42   2023-11-30 20:17:15              1.0
#
# ...

# %% [markdown]
# Did you notice something different in the `RatecodeID` column for above records?

# %%
# Analyse RatecodeID for the negative fare amounts
df[df['fare_amount'] < 0]['RatecodeID'].value_counts()
# Out:
# RatecodeID
# 1.0    2353
# 2.0     193
# 5.0      40
# 3.0      27
# 4.0      12
# Name: count, dtype: int64

# %%
# Find which columns have negative values
neg_cols = df.select_dtypes(include=['number']).columns
negative_value_counts = (df[neg_cols] < 0).sum()
negative_value_counts[negative_value_counts > 0]
# Out:
# fare_amount              2668
# extra                    1344
# mta_tax                  2571
# tip_amount                 11
# tolls_amount              169
# improvement_surcharge    2638
# total_amount             2641
# congestion_surcharge     2117
# Airport_fee               353
# dtype: int64

# %%
# fix these negative values
cols_with_negatives = [
    'fare_amount', 'extra', 'mta_tax', 'tip_amount',
    'tolls_amount', 'improvement_surcharge', 'total_amount',
    'congestion_surcharge', 'Airport_fee'
]

for col in cols_with_negatives:
    df[col] = df[col].clip(lower=0)

(df[cols_with_negatives] < 0).sum()
# Out:
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# congestion_surcharge     0
# Airport_fee              0
# dtype: int64

# %% [markdown]
# ### **2.2** Handling Missing Values
# <font color = red>[10 marks]</font> <br>

# %% [markdown]
# **2.2.1**  <font color = red>[2 marks]</font> <br>
# Find the proportion of missing values in each column

# %%
# Find the proportion of missing values in each column
df.isnull().sum()
# Out:
# VendorID                    0
# tpep_pickup_datetime        0
# tpep_dropoff_datetime       0
# passenger_count          8887
# trip_distance               0
# RatecodeID               8887
# store_and_fwd_flag       8887
# PULocationID                0
# DOLocationID                0
# payment_type                0
# fare_amount                 0
# extra                       0
# mta_tax                     0
# tip_amount                  0
# tolls_amount                0
# improvement_surcharge       0
# total_amount                0
# congestion_surcharge     8887
# date                        0
# hour                        0
# Airport_fee              8887
# dtype: int64

# %% [markdown]
# **2.2.2**  <font color = red>[3 marks]</font> <br>
# Handling missing values in `passenger_count`

# %%
# Display the rows with null values
# Impute NaN values in 'passenger_count'
mean_passenger_count = df['passenger_count'].mean().round()
df[df['passenger_count'].isnull()]
df['passenger_count'].fillna(mean_passenger_count, inplace=True)
# Out:
# <ipython-input-27-f6a7e1942724>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['passenger_count'].fillna(mean_passenger_count, inplace=True)

# %% [markdown]
# Did you find zeroes in passenger_count? Handle these.

# %%
# checking if any row has passenger_count equalto zero
df['passenger_count'].value_counts()
df[df['passenger_count']==0]
df.loc[df['passenger_count'] == 0, 'passenger_count'] = mean_passenger_count

# %% [markdown]
# **2.2.3**  <font color = red>[2 marks]</font> <br>
# Handle missing values in `RatecodeID`

# %%
# Fix missing values in 'RatecodeID'
mode_val = df['RatecodeID'].mode()[0]
df['RatecodeID'].fillna(mode_val, inplace=True)
df['RatecodeID']
# Out:
# <ipython-input-29-6f68c277a3eb>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['RatecodeID'].fillna(mode_val, inplace=True)
# 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         2.0
#          ...
# 268145    1.0
# 268146    1.0
# 268147    1.0
# 268148    1.0
# 268149    1.0
# Name: RatecodeID, Length: 268150, dtype: float64

# %% [markdown]
# **2.2.4**  <font color = red>[3 marks]</font> <br>
# Impute NaN in `congestion_surcharge`

# %%
# handle null values in congestion_surcharge
df['congestion_surcharge'].fillna(0, inplace=True)

df[df['congestion_surcharge'].isnull()].value_counts()
# Out:
# <ipython-input-30-a34180b7f340>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['congestion_surcharge'].fillna(0, inplace=True)
# Series([], Name: count, dtype: int64)

# %% [markdown]
# Are there missing values in other columns? Did you find NaN values in some other set of columns? Handle those missing values below.

# %%
# Handle any remaining missing values

# df.isnull().sum()
df['Airport_fee'].fillna(df['Airport_fee'].mean(), inplace=True)
df['store_and_fwd_flag'].fillna('N', inplace=True)
# df.head()
# Out:
# <ipython-input-31-928524962db5>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Airport_fee'].fillna(df['Airport_fee'].mean(), inplace=True)
# <ipython-input-31-928524962db5>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# ### **2.3** Handling Outliers
# <font color = red>[10 marks]</font> <br>

# %% [markdown]
# Before we start fixing outliers, let's perform outlier analysis.

# %%
# Describe the data and check if there are any potential outliers present
# Check for potential out of place values in various columns
# df.isna().sum()
# df.isnull().sum()
df.describe()
# Out:
#             VendorID  passenger_count  trip_distance     RatecodeID  \
# count  268150.000000    268150.000000  268150.000000  268150.000000
# mean        1.736804         1.373839       4.349966       1.609208
# std         0.444583         0.864965     266.246479       7.231465
# min         1.000000         1.000000       0.000000       1.000000
# 25%         1.000000         1.000000       1.040000       1.000000
# 50%         2.000000         1.000000       1.780000       1.000000
# 75%         2.000000         1.000000       3.400000       1.000000
# max         6.000000         8.000000  116439.710000      99.000000
#
#         PULocationID   DOLocationID   payment_type    fare_amount  \
# count  268150.000000  268150.000000  268150.000000  268150.000000
# mean      165.026459     163.957505       1.186705      19.668882
# std        64.086976      69.831952       0.556279      18.471835
# min         1.000000       1.000000       0.000000       0.000000
# ...

# %% [markdown]
# **2.3.1**  <font color = red>[10 marks]</font> <br>
# Based on the above analysis, it seems that some of the outliers are present due to errors in registering the trips. Fix the outliers.
#
# Some points you can look for:
# - Entries where `trip_distance` is nearly 0 and `fare_amount` is more than 300
# - Entries where `trip_distance` and `fare_amount` are 0 but the pickup and dropoff zones are different (both distance and fare should not be zero for different zones)
# - Entries where `trip_distance` is more than 250  miles.
# - Entries where `payment_type` is 0 (there is no payment_type 0 defined in the data dictionary)
#
# These are just some suggestions. You can handle outliers in any way you wish, using the insights from above outlier analysis.

# %% [markdown]
# How will you fix each of these values? Which ones will you drop and which ones will you replace?

# %% [markdown]
# First, let us remove 7+ passenger counts as there are very less instances.

# %%
# remove passenger_count > 6
df = df[df['passenger_count'] <= 6]


df['passenger_count'].value_counts()
# Out:
# passenger_count
# 1.0    207742
# 2.0     39572
# 3.0      9674
# 4.0      5562
# 5.0      3367
# 6.0      2230
# Name: count, dtype: int64

# %%
# Continue with outlier handling

df = df[df['trip_distance'] < 250]
df = df[df['payment_type'] != 0]
df = df[(df['trip_distance'] >= 1) &
        (df['fare_amount'] < 300) &
        (df['PULocationID'] != df['DOLocationID'])]
df = df[(df['trip_distance'] != 0) & (df['fare_amount'] != 0)]
df.describe()
# Out:
#             VendorID  passenger_count  trip_distance     RatecodeID  \
# count  196560.000000    196560.000000  196560.000000  196560.000000
# mean        1.738217         1.396001       4.251711       1.663370
# std         0.439606         0.884184       4.828894       7.581995
# min         1.000000         1.000000       1.000000       1.000000
# 25%         1.000000         1.000000       1.500000       1.000000
# 50%         2.000000         1.000000       2.260000       1.000000
# 75%         2.000000         1.000000       4.340000       1.000000
# max         2.000000         6.000000      63.860000      99.000000
#
#         PULocationID   DOLocationID   payment_type    fare_amount  \
# count  196560.000000  196560.000000  196560.000000  196560.000000
# mean      162.722273     161.470966       1.184605      22.813599
# std        62.935162      70.635247       0.436760      18.394440
# min         1.000000       1.000000       1.000000       0.010000
# ...

# %%
# Do any columns need standardising?

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df[['fare_amount', 'trip_distance', 'tip_amount', 'total_amount']] = scaler.fit_transform(
    df[['fare_amount', 'trip_distance', 'tip_amount', 'total_amount']]
)
df.describe()
# Out:
#             VendorID  passenger_count  trip_distance     RatecodeID  \
# count  196560.000000    196560.000000   1.965600e+05  196560.000000
# mean        1.738217         1.396001   3.065427e-17       1.663370
# std         0.439606         0.884184   1.000003e+00       7.581995
# min         1.000000         1.000000  -6.733880e-01       1.000000
# 25%         1.000000         1.000000  -5.698443e-01       1.000000
# 50%         2.000000         1.000000  -4.124580e-01       1.000000
# 75%         2.000000         1.000000   1.828354e-02       1.000000
# max         2.000000         6.000000   1.234412e+01      99.000000
#
#         PULocationID   DOLocationID   payment_type   fare_amount  \
# count  196560.000000  196560.000000  196560.000000  1.965600e+05
# mean      162.722273     161.470966       1.184605 -1.992527e-16
# std        62.935162      70.635247       0.436760  1.000003e+00
# min         1.000000       1.000000       1.000000 -1.239704e+00
# ...

# %% [markdown]
# ## **3** Exploratory Data Analysis
# <font color = red>[90 marks]</font> <br>

# %%
df.columns.tolist()
# Out:
# ['VendorID',
#  'tpep_pickup_datetime',
#  'tpep_dropoff_datetime',
#  'passenger_count',
#  'trip_distance',
#  'RatecodeID',
#  'store_and_fwd_flag',
#  'PULocationID',
#  'DOLocationID',
#  'payment_type',
#  'fare_amount',
#  'extra',
#  'mta_tax',
#  'tip_amount',
#  'tolls_amount',
#  'improvement_surcharge',
#  'total_amount',
#  'congestion_surcharge',
#  'date',
#  'hour',
#  'Airport_fee']

# %% [markdown]
# #### **3.1** General EDA: Finding Patterns and Trends
# <font color = red>[40 marks]</font> <br>

# %% [markdown]
# **3.1.1** <font color = red>[3 marks]</font> <br>
# Categorise the varaibles into Numerical or Categorical.
# * `VendorID`:
# * `tpep_pickup_datetime`:
# * `tpep_dropoff_datetime`:
# * `passenger_count`:
# * `trip_distance`:
# * `RatecodeID`:
# * `PULocationID`:
# * `DOLocationID`:
# * `payment_type`:
# * `pickup_hour`:
# * `trip_duration`:
#
#
# The following monetary parameters belong in the same category, is it categorical or numerical?
#
#
# * `fare_amount`
# * `extra`
# * `mta_tax`
# * `tip_amount`
# * `tolls_amount`
# * `improvement_surcharge`
# * `total_amount`
# * `congestion_surcharge`
# * `airport_fee`

# %% [markdown]
# ##### Temporal Analysis

# %% [markdown]
# **3.1.2** <font color = red>[5 marks]</font> <br>
# Analyse the distribution of taxi pickups by hours, days of the week, and months.

# %%
# Find and show the hourly trends in taxi pickups
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])

# Extract hour, weekday, and month
df['hour'] = df['tpep_pickup_datetime'].dt.hour
df['weekday'] = df['tpep_pickup_datetime'].dt.day_name()
df['month'] = df['tpep_pickup_datetime'].dt.month_name()

import seaborn as sns
import matplotlib.pyplot as plt

# Hourly trend
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='hour', order=sorted(df['hour'].unique()))
plt.title('Hourly Taxi Pickups')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Pickups')
plt.grid(True)
plt.show()

# %%
# Find and show the daily trends in taxi pickups (days of the week)

plt.figure(figsize=(10,6))
sns.countplot(data=df, x='weekday', order=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
plt.title('Taxi Pickups by Day of Week')
plt.xlabel('Day')
plt.ylabel('Number of Pickups')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# Show the monthly trends in pickups

plt.figure(figsize=(10,6))
sns.countplot(data=df, x='month', order=[
    'January', 'February', 'March', 'April', 'May', 'June',
    'July', 'August', 'September', 'October', 'November', 'December'
])
plt.title('Monthly Taxi Pickups')
plt.xlabel('Month')
plt.ylabel('Number of Pickups')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# ##### Financial Analysis

# %% [markdown]
# Take a look at the financial parameters like `fare_amount`, `tip_amount`, `total_amount`, and also `trip_distance`. Do these contain zero/negative values?

# %%
# Analyse the above parameters

cols = ['fare_amount', 'tip_amount', 'total_amount', 'trip_distance']

for col in cols:
    zero_count = (df[col] == 0).sum()
    neg_count = (df[col] < 0).sum()
    print(f"{col}: {zero_count} zeroes, {neg_count} negatives")
# Out:
# fare_amount: 0 zeroes, 138881 negatives
# tip_amount: 0 zeroes, 126053 negatives
# total_amount: 0 zeroes, 140987 negatives
# trip_distance: 0 zeroes, 146526 negatives

# %% [markdown]
# Do you think it is beneficial to create a copy DataFrame leaving out the zero values from these?

# %% [markdown]
# **3.1.3** <font color = red>[2 marks]</font> <br>
# Filter out the zero values from the above columns.
#
# **Note:** The distance might be 0 in cases where pickup and drop is in the same zone. Do you think it is suitable to drop such cases of zero distance?

# %%
# # Create a df with non zero entries for the selected parameters.
# df = df[(df['trip_distance'] >= 1) & (df['fare_amount'] < 300) &  (df['PULocationID'] != df['DOLocationID'])]
### The requied parameters are already performed in the Continue with outlier handling ###

# %% [markdown]
# **3.1.4** <font color = red>[3 marks]</font> <br>
# Analyse the monthly revenue (`total_amount`) trend

# %%
# Group data by month and analyse monthly revenue

df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
df['month'] = df['tpep_pickup_datetime'].dt.month_name()
df['month_num'] = df['tpep_pickup_datetime'].dt.month

monthly_revenue = df.groupby(['month_num', 'month'])['total_amount'].sum().reset_index()
monthly_revenue = monthly_revenue.sort_values('month_num')

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.barplot(data=monthly_revenue, x='month', y='total_amount', palette='viridis')
plt.title('Monthly Total Revenue from Taxi Trips')
plt.xlabel('Month')
plt.ylabel('Total Revenue ($)')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-42-b056ac4aa6d6>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=monthly_revenue, x='month', y='total_amount', palette='viridis')

# %% [markdown]
# **3.1.5** <font color = red>[3 marks]</font> <br>
# Show the proportion of each quarter of the year in the revenue

# %%
# Calculate proportion of each quarter
# Make sure 'tpep_pickup_datetime' is in datetime format
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])

# Create a 'quarter' column
df['quarter'] = df['tpep_pickup_datetime'].dt.quarter

# Group by quarter and sum total_amount
quarterly_revenue = df.groupby('quarter')['total_amount'].sum().reset_index()
quarterly_revenue = quarterly_revenue[quarterly_revenue['total_amount'] > 0]
quarterly_revenue['total_amount'] = quarterly_revenue['total_amount'].abs()

total_revenue = quarterly_revenue['total_amount'].sum()
quarterly_revenue['proportion'] = quarterly_revenue['total_amount'] / total_revenue
quarterly_revenue['percentage'] = (quarterly_revenue['proportion'] * 100).round(2)
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
plt.pie(quarterly_revenue['proportion'], labels=[f"Q{q}" for q in quarterly_revenue['quarter']],
        autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'))
plt.title('Revenue Contribution by Quarter')
plt.axis('equal')
plt.show()

# %% [markdown]
# **3.1.6** <font color = red>[3 marks]</font> <br>
# Visualise the relationship between `trip_distance` and `fare_amount`. Also find the correlation value for these two.
#
# **Hint:** You can leave out the trips with trip_distance = 0

# %%
# Show how trip fare is affected by distance
df_filtered = df[df['trip_distance'] > 0]
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_filtered, x='trip_distance', y='fare_amount', color='blue')
plt.title('Relationship Between Trip Distance and Fare Amount')
plt.xlabel('Trip Distance (miles)')
plt.ylabel('Fare Amount ($)')
plt.grid(True)
plt.show()
correlation = df_filtered[['trip_distance', 'fare_amount']].corr().iloc[0, 1]
print(f"Correlation between trip_distance and fare_amount: {correlation:.2f}")
# Out:
# Correlation between trip_distance and fare_amount: 0.92

# %% [markdown]
# **3.1.7** <font color = red>[5 marks]</font> <br>
# Find and visualise the correlation between:
# 1. `fare_amount` and trip duration (pickup time to dropoff time)
# 2. `fare_amount` and `passenger_count`
# 3. `tip_amount` and `trip_distance`

# %%
# Show relationship between fare and trip duration

df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])
df['trip_duration'] = (df['tpep_dropoff_datetime'] - df['tpep_pickup_datetime']).dt.total_seconds() / 60  # in minutes
df_filtered = df[df['trip_duration'] > 0]
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_filtered, x='trip_duration', y='fare_amount', color='green')
plt.title('Relationship Between Fare Amount and Trip Duration')
plt.xlabel('Trip Duration (minutes)')
plt.ylabel('Fare Amount ($)')
plt.grid(True)
plt.show()
correlation = df_filtered[['trip_duration', 'fare_amount']].corr().iloc[0, 1]
print(f"Correlation between trip_duration and fare_amount: {correlation:.2f}")
# Out:
# Correlation between trip_duration and fare_amount: 0.26

# %%
# Show relationship between fare and number of passengers

df_filtered = df[df['passenger_count'] > 0]
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_filtered, x='passenger_count', y='fare_amount', color='purple')
plt.title('Relationship Between Fare Amount and Number of Passengers')
plt.xlabel('Number of Passengers')
plt.ylabel('Fare Amount ($)')
plt.grid(True)
plt.show()
correlation = df_filtered[['passenger_count', 'fare_amount']].corr().iloc[0, 1]
print(f"Correlation between passenger_count and fare_amount: {correlation:.2f}")
# Out:
# Correlation between passenger_count and fare_amount: 0.04

# %%
# Show relationship between tip and trip distance

df_filtered = df[(df['tip_amount'] > 0) & (df['trip_distance'] > 0)]
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_filtered, x='trip_distance', y='tip_amount', color='orange')
plt.title('Relationship Between Tip Amount and Trip Distance')
plt.xlabel('Trip Distance (miles)')
plt.ylabel('Tip Amount ($)')
plt.grid(True)
plt.show()
correlation = df_filtered[['tip_amount', 'trip_distance']].corr().iloc[0, 1]
print(f"Correlation between tip_amount and trip_distance: {correlation:.2f}")
# Out:
# Correlation between tip_amount and trip_distance: 0.67

# %% [markdown]
# **3.1.8** <font color = red>[3 marks]</font> <br>
# Analyse the distribution of different payment types (`payment_type`)

# %%
# Analyse the distribution of different payment types (payment_type).
df['payment_type'].unique()
payment_type_counts = df['payment_type'].value_counts()
print(payment_type_counts)
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.barplot(x=payment_type_counts.index, y=payment_type_counts.values, palette='viridis')
plt.title('Distribution of Payment Types')
plt.xlabel('Payment Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# payment_type
# 1    163087
# 2     31801
# 4      1141
# 3       531
# Name: count, dtype: int64
# <ipython-input-48-a492b8573456>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=payment_type_counts.index, y=payment_type_counts.values, palette='viridis')

# %% [markdown]
# - 1= Credit card
# - 2= Cash
# - 3= No charge
# - 4= Dispute

# %% [markdown]
# ##### Geographical Analysis

# %% [markdown]
# For this, you have to use the *taxi_zones.shp* file from the *taxi_zones* folder.
#
# There would be multiple files inside the folder (such as *.shx, .sbx, .sbn* etc). You do not need to import/read any of the files other than the shapefile, *taxi_zones.shp*.
#
# Do not change any folder structure - all the files need to be present inside the folder for it to work.
#
# The folder structure should look like this:
# ```
# Taxi Zones
# |- taxi_zones.shp.xml
# |- taxi_zones.prj
# |- taxi_zones.sbn
# |- taxi_zones.shp
# |- taxi_zones.dbf
# |- taxi_zones.shx
# |- taxi_zones.sbx
#
#  ```
#
#  You only need to read the `taxi_zones.shp` file. The *shp* file will utilise the other files by itself.

# %% [markdown]
# We will use the *GeoPandas* library for geopgraphical analysis
# ```
# import geopandas as gpd
# ```
#
# More about geopandas and shapefiles: [About](https://geopandas.org/en/stable/about.html)
#
#
# Reading the shapefile is very similar to *Pandas*. Use `gpd.read_file()` function to load the data (*taxi_zones.shp*) as a GeoDataFrame. Documentation: [Reading and Writing Files](https://geopandas.org/en/stable/docs/user_guide/io.html)

# %%
# %pip install geopandas

# %% [markdown]
# **3.1.9** <font color = red>[2 marks]</font> <br>
# Load the shapefile and display it.

# %%
# import geopandas as gpd
import geopandas as gpd
from google.colab import drive
drive.mount('/content/drive')

# Read the shapefile using geopandas
zones =gpd.read_file('/content/drive/MyDrive/data_files/taxi_zones.shp')
zones.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    OBJECTID  Shape_Leng  Shape_Area                     zone  LocationID  \
# 0         1    0.116357    0.000782           Newark Airport           1
# 1         2    0.433470    0.004866              Jamaica Bay           2
# 2         3    0.084341    0.000314  Allerton/Pelham Gardens           3
# 3         4    0.043567    0.000112            Alphabet City           4
# 4         5    0.092146    0.000498            Arden Heights           5
#
#          borough                                           geometry
# 0            EWR  POLYGON ((933100.918 192536.086, 933091.011 19...
# 1         Queens  MULTIPOLYGON (((1033269.244 172126.008, 103343...
# 2          Bronx  POLYGON ((1026308.77 256767.698, 1026495.593 2...
# 3      Manhattan  POLYGON ((992073.467 203714.076, 992068.667 20...
# ...

# %% [markdown]
# Now, if you look at the DataFrame created, you will see columns like: `OBJECTID`,`Shape_Leng`, `Shape_Area`, `zone`, `LocationID`, `borough`, `geometry`.
# <br><br>
#
# Now, the `locationID` here is also what we are using to mark pickup and drop zones in the trip records.
#
# The geometric parameters like shape length, shape area and geometry are used to plot the zones on a map.
#
# This can be easily done using the `plot()` method.

# %%
print(zones.info())
zones.plot()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    263 non-null    int32
#  1   Shape_Leng  263 non-null    float64
#  2   Shape_Area  263 non-null    float64
#  3   zone        263 non-null    object
#  4   LocationID  263 non-null    int32
#  5   borough     263 non-null    object
#  6   geometry    263 non-null    geometry
# dtypes: float64(2), geometry(1), int32(2), object(2)
# memory usage: 12.5+ KB
# None
# <Axes: >

# %% [markdown]
# Now, you have to merge the trip records and zones data using the location IDs.

# %% [markdown]
# **3.1.10** <font color = red>[3 marks]</font> <br>
# Merge the zones data into trip data using the `locationID` and `PULocationID` columns.

# %%
# Merge zones and trip records using locationID and PULocationID
trips = df
merged_df=df.merge(zones,how="left",left_on="PULocationID",right_on="LocationID")
merged_df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2023-01-01 00:47:17   2023-01-01 01:07:01              2.0
# 1         2  2023-01-01 00:06:02   2023-01-01 00:31:38              1.0
# 2         2  2023-01-01 00:02:19   2023-01-01 00:30:49              1.0
# 3         2  2023-01-01 00:13:54   2023-01-01 00:21:26              1.0
# 4         2  2023-01-01 00:47:17   2023-01-01 01:05:27              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0      -0.279922         1.0                  N           142           170
# 1      -0.362757         1.0                  N            43           161
# 2       3.337893         2.0                  N           132           140
# 3      -0.460088         1.0                  N           142            75
# 4      -0.335836         1.0                  N           163            79
#
# ...

# %% [markdown]
# **3.1.11** <font color = red>[3 marks]</font> <br>
# Group data by location IDs to find the total number of trips per location ID

# %%
# Group data by location and calculate the number of trips

trip_count = df.groupby("PULocationID").size().reset_index(name="trip_count")
trip_count = trip_count.sort_values(by="trip_count",ascending=False)
trip_count.head()
# Out:
#      PULocationID  trip_count
# 113           132       12980
# 141           161        8821
# 119           138        8745
# 211           237        7877
# 210           236        7687

# %% [markdown]
# **3.1.12** <font color = red>[2 marks]</font> <br>
# Now, use the grouped data to add number of trips to the GeoDataFrame.
#
# We will use this to plot a map of zones showing total trips per zone.

# %%
# Merge trip counts back to the zones GeoDataFrame

merged_zones=zones.merge(trip_count,how="left",left_on="LocationID",right_on="PULocationID")
merged_zones["trip_count"]=merged_zones["trip_count"].fillna(0)
merged_zones["trip_count"]=merged_zones['trip_count'].astype(int)
merged_zones= merged_zones.drop(columns=["PULocationID"])
merged_zones.head()
# Out:
#      OBJECTID  Shape_Leng  Shape_Area                   zone  LocationID  \
# 131       132    0.245479    0.002038            JFK Airport         132
# 160       161    0.035804    0.000072         Midtown Center         161
# 137       138    0.107467    0.000537      LaGuardia Airport         138
# 236       237    0.042213    0.000096  Upper East Side South         237
# 235       236    0.044252    0.000103  Upper East Side North         236
#
#        borough                                           geometry  trip_count
# 131     Queens  MULTIPOLYGON (((1032791.001 181085.006, 103283...       12980
# 160  Manhattan  POLYGON ((991081.026 214453.698, 990952.644 21...        8821
# 137     Queens  MULTIPOLYGON (((1019904.219 225677.983, 102031...        8745
# 236  Manhattan  POLYGON ((993633.442 216961.016, 993507.232 21...        7877
# 235  Manhattan  POLYGON ((995940.048 221122.92, 995812.322 220...        7687

# %% [markdown]
# The next step is creating a color map (choropleth map) showing zones by the number of trips taken.
#
# Again, you can use the `zones.plot()` method for this. [Plot Method GPD](https://geopandas.org/en/stable/docs/reference/api/geopandas.GeoDataFrame.plot.html#geopandas.GeoDataFrame.plot)
#
# But first, you need to define the figure and axis for the plot.
#
# `fig, ax = plt.subplots(1, 1, figsize = (12, 10))`
#
# This function creates a figure (fig) and a single subplot (ax)
#
# ---

# %% [markdown]
# After setting up the figure and axis, we can proceed to plot the GeoDataFrame on this axis. This is done in the next step where we use the plot method of the GeoDataFrame.
#
# You can define the following parameters in the `zones.plot()` method:
# ```
# column = '',
# ax = ax,
# legend = True,
# legend_kwds = {'label': "label", 'orientation': "<horizontal/vertical>"}
# ```
#
# To display the plot, use `plt.show()`.

# %% [markdown]
# **3.1.13** <font color = red>[3 marks]</font> <br>
# Plot a color-coded map showing zone-wise trips

# %%
# Define figure and axis
fig, ax = plt.subplots(1, 1, figsize = (12, 10))

merged_zones.plot(
    column = 'trip_count',
    ax = ax,
    legend = True,
    legend_kwds = {'label': "Number of Trips", 'orientation': "vertical"}
)

# Plot the map and display it
plt.show()

# %%
# can you try displaying the zones DF sorted by the number of trips?
merged_zones = merged_zones.sort_values(by="trip_count",ascending=False)
merged_zones.head()
# Out:
#      OBJECTID  Shape_Leng  Shape_Area                   zone  LocationID  \
# 131       132    0.245479    0.002038            JFK Airport         132
# 160       161    0.035804    0.000072         Midtown Center         161
# 137       138    0.107467    0.000537      LaGuardia Airport         138
# 236       237    0.042213    0.000096  Upper East Side South         237
# 235       236    0.044252    0.000103  Upper East Side North         236
#
#        borough                                           geometry  trip_count
# 131     Queens  MULTIPOLYGON (((1032791.001 181085.006, 103283...       12980
# 160  Manhattan  POLYGON ((991081.026 214453.698, 990952.644 21...        8821
# 137     Queens  MULTIPOLYGON (((1019904.219 225677.983, 102031...        8745
# 236  Manhattan  POLYGON ((993633.442 216961.016, 993507.232 21...        7877
# 235  Manhattan  POLYGON ((995940.048 221122.92, 995812.322 220...        7687

# %% [markdown]
# Here we have completed the temporal, financial and geographical analysis on the trip records.
#
# **Compile your findings from general analysis below:**

# %% [markdown]
# You can consider the following points:
#
# * Busiest hours, days and months
# * Trends in revenue collected
# * Trends in quarterly revenue
# * How fare depends on trip distance, trip duration and passenger counts
# * How tip amount depends on trip distance
# * Busiest zones

# %% [markdown]
# #### **3.2** Detailed EDA: Insights and Strategies
# <font color = red>[50 marks]</font> <br>

# %% [markdown]
# Having performed basic analyses for finding trends and patterns, we will now move on to some detailed analysis focussed on operational efficiency, pricing strategies, and customer experience.

# %% [markdown]
# ##### Operational Efficiency

# %% [markdown]
# Analyze variations by time of day and location to identify bottlenecks or inefficiencies in routes

# %% [markdown]
# **3.2.1** <font color = red>[3 marks]</font> <br>
# Identify slow routes by calculating the average time taken by cabs to get from one zone to another at different hours of the day.

# %% [markdown]
# Speed on a route *X* for hour *Y* = (*distance of the route X / average trip duration for hour Y*)

# %%
# Find routes which have the slowest speeds at different times of the day

df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])

df['trip_duration'] = (df['tpep_dropoff_datetime'] - df['tpep_pickup_datetime']).dt.total_seconds() / 60

df = df[(df['trip_duration'] > 0) & (df['trip_distance'] > 0)]

df['hour'] = df['tpep_pickup_datetime'].dt.hour

grouped = df.groupby(['PULocationID', 'DOLocationID', 'hour']).agg({
    'trip_distance': 'mean',
    'trip_duration': 'mean'
}).reset_index()

grouped['avg_speed_mph'] = (grouped['trip_distance'] / grouped['trip_duration'])*60

slow_routes = grouped.sort_values(by='avg_speed_mph').head(10)
print(slow_routes)
# Out:
#        PULocationID  DOLocationID  hour  trip_distance  trip_duration  \
# 10248           137            87    17       0.001717     410.166667
# 4050             79           255     1       0.043134    1437.866667
# 2385             68           166    15       0.001717      56.800000
# 16621           164           151    12       0.001717      41.533333
# 21930           238           244    18       0.033815     718.933333
# 6689            125           163    16       0.001717      34.133333
# 19453           230           202    18       0.001717      30.233333
# 12789           140           166    14       0.001717      29.900000
# 14876           158           143    23       0.001717      27.950000
# 23878           263            68    16       0.001717      26.600000
#
#        avg_speed_mph
# 10248       0.000251
# 4050        0.001800
# 2385        0.001813
# 16621       0.002480
# 21930       0.002822
# 6689        0.003017
# 19453       0.003407
# ...

# %% [markdown]
# How does identifying high-traffic, high-demand routes help us?

# %% [markdown]
# **3.2.2** <font color = red>[3 marks]</font> <br>
# Calculate the number of trips at each hour of the day and visualise them. Find the busiest hour and show the number of trips for that hour.

# %%
# Visualise the number of trips per hour and find the busiest hour

df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
df['hour'] = df['tpep_pickup_datetime'].dt.hour

hourly_trips = df.groupby('hour').size().reset_index(name='trip_count')

busiest_hour = hourly_trips.loc[hourly_trips['trip_count'].idxmax()]

plt.figure(figsize=(12,6))
sns.barplot(data=hourly_trips, x='hour', y='trip_count', palette='viridis')
plt.title('Number of Trips by Hour of the Day')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Trips')
plt.xticks(range(0,24))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-80-78c4dc58c0e3>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=hourly_trips, x='hour', y='trip_count', palette='viridis')

# %% [markdown]
# Remember, we took a fraction of trips. To find the actual number, you have to scale the number up by the sampling ratio.

# %% [markdown]
# **3.2.3** <font color = red>[2 mark]</font> <br>
# Find the actual number of trips in the five busiest hours

# %%
# Scale up the number of trips

# Fill in the value of your sampling fraction and use that to scale up the numbers
sample_fraction = 0.007

hourly_trip_counts = df.groupby('hour').size().reset_index(name='trip_count')

top_5_hours = hourly_trip_counts.sort_values(by='trip_count', ascending=False).head(5)

top_5_hours['scaled_trip_count'] = (top_5_hours['trip_count'] / sample_fraction).astype(int)

print(top_5_hours)
# Out:
#     hour  trip_count  scaled_trip_count
# 14    14        3133             447571
# 16    16        3064             437714
# 15    15        3058             436857
# 21    21        2962             423142
# 20    20        2943             420428

# %% [markdown]
# **3.2.4** <font color = red>[3 marks]</font> <br>
# Compare hourly traffic pattern on weekdays. Also compare for weekend.

# %%
# Compare traffic trends for the week days and weekends
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
df['weekday'] = df['tpep_pickup_datetime'].dt.dayofweek

df['is_weekend'] = df['weekday'].apply(lambda x: 'Weekend' if x >= 5 else 'Weekday')

hourly_trips = df.groupby(['hour', 'is_weekend']).size().reset_index(name='trip_count')

plt.figure(figsize=(10,6))
sns.lineplot(data=hourly_trips, x='hour', y='trip_count', hue='is_weekend', marker='o')
plt.title('Hourly Traffic Pattern: Weekday vs Weekend')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Trips')
plt.grid(True)
plt.xticks(range(0, 24))
plt.legend(title='Day Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# What can you infer from the above patterns? How will finding busy and quiet hours for each day help us?

# %% [markdown]
# **3.2.5** <font color = red>[3 marks]</font> <br>
# Identify top 10 zones with high hourly pickups. Do the same for hourly dropoffs. Show pickup and dropoff trends in these zones.

# %%
# Find top 10 pickup and dropoff zones
top_pickup_zones = df["PULocationID"].value_counts().head(10).index.tolist()

top_dropoff_zones = df['DOLocationID'].value_counts().head(10).index.tolist()

pickup_data = df[df['PULocationID'].isin(top_pickup_zones)]
dropoff_data = df[df['DOLocationID'].isin(top_dropoff_zones)]

pickup_trends = pickup_data.groupby(['hour', 'PULocationID']).size().reset_index(name='pickup_count')
dropoff_trends = dropoff_data.groupby(['hour', 'DOLocationID']).size().reset_index(name='dropoff_count')

import seaborn as sns
import matplotlib.pyplot as plt

# Pickups
plt.figure(figsize=(12,6))
sns.lineplot(data=pickup_trends, x='hour', y='pickup_count', hue='PULocationID', marker='o')
plt.title('Hourly Pickup Trends for Top 10 Zones')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Pickups')
plt.xticks(range(0, 24))
plt.grid(True)
plt.legend(title='Pickup Zone', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# Dropoffs
plt.figure(figsize=(12,6))
sns.lineplot(data=dropoff_trends, x='hour', y='dropoff_count', hue='DOLocationID', marker='o')
plt.title('Hourly Dropoff Trends for Top 10 Zones')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Dropoffs')
plt.xticks(range(0, 24))
plt.grid(True)
plt.legend(title='Dropoff Zone', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# **3.2.6** <font color = red>[3 marks]</font> <br>
# Find the ratio of pickups and dropoffs in each zone. Display the 10 highest (pickup/drop) and 10 lowest (pickup/drop) ratios.

# %%
# Find the top 10 and bottom 10 pickup/dropoff ratios


pickup_counts = df['PULocationID'].value_counts().rename('pickup_count')
dropoff_counts = df['DOLocationID'].value_counts().rename('dropoff_count')


zone_counts = pd.concat([pickup_counts, dropoff_counts], axis=1).fillna(0)


zone_counts['dropoff_count'] = zone_counts['dropoff_count'].replace(0, 1e-6)


zone_counts['pickup_dropoff_ratio'] = zone_counts['pickup_count'] / zone_counts['dropoff_count']


top_10 = zone_counts.sort_values(by='pickup_dropoff_ratio', ascending=False).head(10)


bottom_10 = zone_counts.sort_values(by='pickup_dropoff_ratio', ascending=True).head(10)


print("Top 10 Zones by Pickup/Dropoff Ratio:")
print(top_10)

print("\nBottom 10 Zones by Pickup/Dropoff Ratio:")
print(bottom_10)
# Out:
# Top 10 Zones by Pickup/Dropoff Ratio:
#      pickup_count  dropoff_count  pickup_dropoff_ratio
# 207           3.0       0.000001          3.000000e+06
# 70         1072.0      84.000000          1.276190e+01
# 132       12624.0    2403.000000          5.253433e+00
# 138        8322.0    2930.000000          2.840273e+00
# 186         919.0     364.000000          2.524725e+00
# 249         710.0     342.000000          2.076023e+00
# 264         196.0      95.000000          2.063158e+00
# 253           2.0       1.000000          2.000000e+00
# 114         457.0     282.000000          1.620567e+00
# 234         594.0     376.000000          1.579787e+00
#
# Bottom 10 Zones by Pickup/Dropoff Ratio:
#      pickup_count  dropoff_count  pickup_dropoff_ratio
# 54            0.0           46.0                   0.0
# 36            0.0          156.0                   0.0
# 126           0.0           23.0                   0.0
# 192           0.0           34.0                   0.0
# ...

# %% [markdown]
# **3.2.7** <font color = red>[3 marks]</font> <br>
# Identify zones with high pickup and dropoff traffic during night hours (11PM to 5AM)

# %%
# During night hours (11pm to 5am) find the top 10 pickup and dropoff zones
# Note that the top zones should be of night hours and not the overall top zones


night_hours = df[(df['hour'] >= 23) | (df['hour'] <= 5)]


top_night_pickups = night_hours['PULocationID'].value_counts().head(10)


top_night_dropoffs = night_hours['DOLocationID'].value_counts().head(10)


print("Top 10 Nighttime Pickup Zones:")
print(top_night_pickups)

print("\nTop 10 Nighttime Dropoff Zones:")
print(top_night_dropoffs)
# Out:
# Top 10 Nighttime Pickup Zones:
# PULocationID
# 132    1849
# 138     766
# 79      384
# 249     330
# 48      301
# 148     265
# 230     256
# 114     238
# 186     182
# 68      180
# Name: count, dtype: int64
#
# Top 10 Nighttime Dropoff Zones:
# DOLocationID
# 138    246
# 263    203
# 132    179
# 238    170
# 265    165
# 239    159
# 262    153
# 7      151
# 42     144
# 41     133
# Name: count, dtype: int64

# %% [markdown]
# Now, let us find the revenue share for the night time hours and the day time hours. After this, we will move to deciding a pricing strategy.
#
# **3.2.8** <font color = red>[2 marks]</font> <br>
# Find the revenue share for nighttime and daytime hours.

# %%
# Filter for night hours (11 PM to 5 AM)


df['hour'] = pd.to_datetime(df['tpep_pickup_datetime']).dt.hour


night_df = df[(df['hour'] >= 23) | (df['hour'] <= 5)]
day_df = df[(df['hour'] > 5) & (df['hour'] < 23)]


night_revenue = night_df['total_amount'].sum()
day_revenue = day_df['total_amount'].sum()
total_revenue = night_revenue + day_revenue


night_share = (night_revenue / total_revenue) * 100
day_share = (day_revenue / total_revenue) * 100


print(f"Nighttime Revenue Share: {night_share:.2f}%")
print(f"Daytime Revenue Share: {day_share:.2f}%")
# Out:
# Nighttime Revenue Share: 11.75%
# Daytime Revenue Share: 88.25%

# %% [markdown]
# ##### Pricing Strategy

# %% [markdown]
# **3.2.9** <font color = red>[2 marks]</font> <br>
# For the different passenger counts, find the average fare per mile per passenger.
#
# For instance, suppose the average fare per mile for trips with 3 passengers is 3 USD/mile, then the fare per mile per passenger will be 1 USD/mile.

# %%
# Analyse the fare per mile per passenger for different passenger counts

valid_df = df[(df['trip_distance'] > 0) &
              (df['fare_amount'] > 0) &
              (df['passenger_count'] > 0)]


valid_df['fare_per_mile'] = valid_df['fare_amount'] / valid_df['trip_distance']


valid_df['fare_per_mile_per_passenger'] = valid_df['fare_per_mile'] / valid_df['passenger_count']


avg_fare = valid_df.groupby('passenger_count')['fare_per_mile_per_passenger'].mean().reset_index()


avg_fare.columns = ['passenger_count', 'avg_fare_per_mile_per_passenger']
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
sns.barplot(data=avg_fare, x='passenger_count', y='avg_fare_per_mile_per_passenger', palette='viridis')
plt.title('Average Fare per Mile per Passenger by Passenger Count')
plt.xlabel('Passenger Count')
plt.ylabel('Fare per Mile per Passenger (USD)')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-97-417e403a8af1>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_df['fare_per_mile'] = valid_df['fare_amount'] / valid_df['trip_distance']
# <ipython-input-97-417e403a8af1>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_df['fare_per_mile_per_passenger'] = valid_df['fare_per_mile'] / valid_df['passenger_count']
# <ipython-input-97-417e403a8af1>:22: FutureWarning:
#
# ...

# %% [markdown]
# **3.2.10** <font color = red>[3 marks]</font> <br>
# Find the average fare per mile by hours of the day and by days of the week

# %%
# Compare the average fare per mile for different days and for different times of the day

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


valid_df = df[(df['trip_distance'] > 0) & (df['fare_amount'] > 0)]


valid_df['fare_per_mile'] = valid_df['fare_amount'] / valid_df['trip_distance']


valid_df['tpep_pickup_datetime'] = pd.to_datetime(valid_df['tpep_pickup_datetime'])

valid_df['hour_of_day'] = valid_df['tpep_pickup_datetime'].dt.hour
valid_df['day_of_week'] = valid_df['tpep_pickup_datetime'].dt.dayofweek  # 0=Monday, 6=Sunday


avg_fare_by_hour = valid_df.groupby('hour_of_day')['fare_per_mile'].mean().reset_index()


avg_fare_by_day = valid_df.groupby('day_of_week')['fare_per_mile'].mean().reset_index()


avg_fare_by_hour.columns = ['hour_of_day', 'avg_fare_per_mile']
avg_fare_by_day.columns = ['day_of_week', 'avg_fare_per_mile']


plt.figure(figsize=(10, 5))
sns.lineplot(data=avg_fare_by_hour, x='hour_of_day', y='avg_fare_per_mile', marker='o', color='b')
plt.title('Average Fare per Mile by Hour of the Day')
plt.xlabel('Hour of the Day')
plt.ylabel('Average Fare per Mile (USD)')
plt.xticks(range(24))
plt.grid(True)
plt.tight_layout()
plt.show()


plt.figure(figsize=(10, 5))
sns.barplot(data=avg_fare_by_day, x='day_of_week', y='avg_fare_per_mile', palette='viridis')
plt.title('Average Fare per Mile by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Average Fare per Mile (USD)')
plt.xticks(ticks=range(7), labels=['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'])
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-98-2dff6b651082>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_df['fare_per_mile'] = valid_df['fare_amount'] / valid_df['trip_distance']
# <ipython-input-98-2dff6b651082>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_df['tpep_pickup_datetime'] = pd.to_datetime(valid_df['tpep_pickup_datetime'])
# <ipython-input-98-2dff6b651082>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# **3.2.11** <font color = red>[3 marks]</font> <br>
# Analyse the average fare per mile for the different vendors for different hours of the day

# %%
# Compare fare per mile for different vendors
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


valid_df = df[(df['trip_distance'] > 0) & (df['fare_amount'] > 0)]


valid_df['fare_per_mile'] = valid_df['fare_amount'] / valid_df['trip_distance']


valid_df['tpep_pickup_datetime'] = pd.to_datetime(valid_df['tpep_pickup_datetime'])


valid_df['hour_of_day'] = valid_df['tpep_pickup_datetime'].dt.hour

avg_fare_by_vendor_hour = valid_df.groupby(['VendorID', 'hour_of_day'])['fare_per_mile'].mean().reset_index()

plt.figure(figsize=(12, 6))
sns.lineplot(data=avg_fare_by_vendor_hour, x='hour_of_day', y='fare_per_mile', hue='VendorID', marker='o')
plt.title('Average Fare per Mile for Different Vendors by Hour of the Day')
plt.xlabel('Hour of the Day')
plt.ylabel('Average Fare per Mile (USD)')
plt.xticks(range(0, 24))
plt.grid(True)
plt.legend(title='VendorID', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-99-e9c3ad330d26>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_df['fare_per_mile'] = valid_df['fare_amount'] / valid_df['trip_distance']
# <ipython-input-99-e9c3ad330d26>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_df['tpep_pickup_datetime'] = pd.to_datetime(valid_df['tpep_pickup_datetime'])
# <ipython-input-99-e9c3ad330d26>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# **3.2.12** <font color = red>[5 marks]</font> <br>
# Compare the fare rates of the different vendors in a tiered fashion. Analyse the average fare per mile for distances upto 2 miles. Analyse the fare per mile for distances from 2 to 5 miles. And then for distances more than 5 miles.

# %%
# Defining distance tiers
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


valid_df = df[(df['trip_distance'] > 0) & (df['fare_amount'] > 0)]

valid_df['fare_per_mile'] = valid_df['fare_amount'] / valid_df['trip_distance']

conditions = [
    (valid_df['trip_distance'] <= 2),
    (valid_df['trip_distance'] > 2) & (valid_df['trip_distance'] <= 5),
    (valid_df['trip_distance'] > 5)
]

distance_labels = ['Up to 2 miles', '2 to 5 miles', 'More than 5 miles']

valid_df['distance_tier'] = pd.cut(valid_df['trip_distance'], bins=[0, 2, 5, float('inf')], labels=distance_labels)

avg_fare_by_vendor_distance = valid_df.groupby(['VendorID', 'distance_tier'])['fare_per_mile'].mean().reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(data=avg_fare_by_vendor_distance, x='distance_tier', y='fare_per_mile', hue='VendorID')
plt.title('Average Fare per Mile for Different Vendors across Distance Tiers')
plt.xlabel('Distance Tier')
plt.ylabel('Average Fare per Mile (USD)')
plt.grid(True)
plt.legend(title='VendorID', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-101-7be44681f2a8>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_df['fare_per_mile'] = valid_df['fare_amount'] / valid_df['trip_distance']
# <ipython-input-101-7be44681f2a8>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_df['distance_tier'] = pd.cut(valid_df['trip_distance'], bins=[0, 2, 5, float('inf')], labels=distance_labels)
# ...

# %% [markdown]
# ##### Customer Experience and Other Factors

# %% [markdown]
# **3.2.13** <font color = red>[5 marks]</font> <br>
# Analyse average tip percentages based on trip distances, passenger counts and time of pickup. What factors lead to low tip percentages?

# %%
#  Analyze tip percentages based on distances, passenger counts and pickup times
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df['tip_percentage'] = (df['tip_amount'] / df['fare_amount']) * 100

df_valid = df[(df['fare_amount'] > 0) & (df['tip_amount'] > 0)]

plt.figure(figsize=(12,6))
sns.scatterplot(data=df_valid, x='trip_distance', y='tip_percentage', hue='trip_distance', palette='viridis', alpha=0.6)
plt.title('Tip Percentage vs. Trip Distance')
plt.xlabel('Trip Distance (miles)')
plt.ylabel('Tip Percentage')
plt.grid(True)
plt.show()

plt.figure(figsize=(12,6))
sns.boxplot(data=df_valid, x='passenger_count', y='tip_percentage')
plt.title('Tip Percentage vs. Passenger Count')
plt.xlabel('Passenger Count')
plt.ylabel('Tip Percentage')
plt.grid(True)
plt.show()

df_valid['pickup_hour'] = pd.to_datetime(df_valid['tpep_pickup_datetime']).dt.hour
plt.figure(figsize=(12,6))
sns.boxplot(data=df_valid, x='pickup_hour', y='tip_percentage')
plt.title('Tip Percentage vs. Hour of Pickup')
plt.xlabel('Pickup Hour of Day')
plt.ylabel('Tip Percentage')
plt.grid(True)
plt.show()


corr_matrix = df_valid[['tip_percentage', 'trip_distance', 'passenger_count', 'pickup_hour']].corr()
print(corr_matrix)


plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Matrix of Tip Percentage and Other Factors')
plt.show()
# Out:
# <ipython-input-104-1906a5ba8aeb>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_valid['pickup_hour'] = pd.to_datetime(df_valid['tpep_pickup_datetime']).dt.hour
#                  tip_percentage  trip_distance  passenger_count  pickup_hour
# tip_percentage         1.000000      -0.293669        -0.015481    -0.007534
# trip_distance         -0.293669       1.000000         0.057422    -0.008069
# passenger_count       -0.015481       0.057422         1.000000    -0.005821
# pickup_hour           -0.007534      -0.008069        -0.005821     1.000000

# %% [markdown]
# Additional analysis [optional]: Let's try comparing cases of low tips with cases of high tips to find out if we find a clear aspect that drives up the tipping behaviours

# %%
# Compare trips with tip percentage < 10% to trips with tip percentage > 25%

df['tip_percentage'] = (df['tip_amount'] / df['total_amount']) * 100

low_tip_trips = df[df['tip_percentage'] < 10]
high_tip_trips = df[df['tip_percentage'] > 25]


avg_trip_distance_low_tip = low_tip_trips['trip_distance'].mean()
avg_trip_distance_high_tip = high_tip_trips['trip_distance'].mean()


avg_passenger_count_low_tip = low_tip_trips['passenger_count'].mean()
avg_passenger_count_high_tip = high_tip_trips['passenger_count'].mean()


avg_fare_low_tip = low_tip_trips['fare_amount'].mean()
avg_fare_high_tip = high_tip_trips['fare_amount'].mean()


low_tip_trips['pickup_datetime'] = pd.to_datetime(low_tip_trips['tpep_pickup_datetime'])
low_tip_trips['dropoff_datetime'] = pd.to_datetime(low_tip_trips['tpep_dropoff_datetime'])
low_tip_trips['trip_duration'] = (low_tip_trips['dropoff_datetime'] - low_tip_trips['pickup_datetime']).dt.total_seconds() / 60

high_tip_trips['pickup_datetime'] = pd.to_datetime(high_tip_trips['tpep_pickup_datetime'])
high_tip_trips['dropoff_datetime'] = pd.to_datetime(high_tip_trips['tpep_dropoff_datetime'])
high_tip_trips['trip_duration'] = (high_tip_trips['dropoff_datetime'] - high_tip_trips['pickup_datetime']).dt.total_seconds() / 60

avg_duration_low_tip = low_tip_trips['trip_duration'].mean()
avg_duration_high_tip = high_tip_trips['trip_duration'].mean()


print("Low Tip Trips (Tip Percentage < 10%)")
print(f"Average Trip Distance: {avg_trip_distance_low_tip} miles")
print(f"Average Passenger Count: {avg_passenger_count_low_tip}")
print(f"Average Fare: ${avg_fare_low_tip}")
print(f"Average Trip Duration: {avg_duration_low_tip} minutes\n")

print("High Tip Trips (Tip Percentage > 25%)")
print(f"Average Trip Distance: {avg_trip_distance_high_tip} miles")
print(f"Average Passenger Count: {avg_passenger_count_high_tip}")
print(f"Average Fare: ${avg_fare_high_tip}")
print(f"Average Trip Duration: {avg_duration_high_tip} minutes")
# Out:
# Low Tip Trips (Tip Percentage < 10%)
# Average Trip Distance: 1.457442763593081 miles
# Average Passenger Count: 1.4768039422738473
# Average Fare: $1.4230029433464801
# Average Trip Duration: 38.606382729086 minutes
#
# High Tip Trips (Tip Percentage > 25%)
# Average Trip Distance: 1.2985418120336853 miles
# Average Passenger Count: 1.4163671392011963
# Average Fare: $1.261294010318472
# Average Trip Duration: 34.240549309409474 minutes
# <ipython-input-106-5ae14b48a511>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   low_tip_trips['pickup_datetime'] = pd.to_datetime(low_tip_trips['tpep_pickup_datetime'])
# <ipython-input-106-5ae14b48a511>:22: SettingWithCopyWarning:
# ...

# %% [markdown]
# **3.2.14** <font color = red>[3 marks]</font> <br>
# Analyse the variation of passenger count across hours and days of the week.

# %%
# See how passenger count varies across hours and days

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df['hour'] = df['tpep_pickup_datetime'].dt.hour
df['day_of_week'] = df['tpep_pickup_datetime'].dt.dayofweek

hourly_passenger_count = df.groupby('hour')['passenger_count'].mean().reset_index()

daily_passenger_count = df.groupby('day_of_week')['passenger_count'].mean().reset_index()

plt.figure(figsize=(10,6))
sns.lineplot(data=hourly_passenger_count, x='hour', y='passenger_count', marker='o', color='b')
plt.title('Variation of Passenger Count Across Hours of the Day')
plt.xlabel('Hour of Day')
plt.ylabel('Average Passenger Count')
plt.xticks(range(24))
plt.grid(True)
plt.tight_layout()
plt.show()

plt.figure(figsize=(10,6))
sns.lineplot(data=daily_passenger_count, x='day_of_week', y='passenger_count', marker='o', color='g')
plt.title('Variation of Passenger Count Across Days of the Week')
plt.xlabel('Day of Week (0=Monday, 6=Sunday)')
plt.ylabel('Average Passenger Count')
plt.xticks(range(7), ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'])
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **3.2.15** <font color = red>[2 marks]</font> <br>
# Analyse the variation of passenger counts across zones

# %%
# How does passenger count vary across zones

zone_passenger_counts = df.groupby('PULocationID')['passenger_count'].sum().reset_index()

zone_passenger_counts = zone_passenger_counts.sort_values(by='passenger_count', ascending=False)

plt.figure(figsize=(12,6))
sns.barplot(x='PULocationID', y='passenger_count', data=zone_passenger_counts)
plt.title('Variation of Passenger Counts Across Zones')
plt.xlabel('Zone (PULocationID)')
plt.ylabel('Total Passenger Count')
plt.xticks(rotation=90)
plt.show()

# %%
# For a more detailed analysis, we can use the zones_with_trips GeoDataFrame
# Create a new column for the average passenger count in each zone.

# %% [markdown]
# Find out how often surcharges/extra charges are applied to understand their prevalance

# %% [markdown]
# **3.2.16** <font color = red>[5 marks]</font> <br>
# Analyse the pickup/dropoff zones or times when extra charges are applied more frequently

# %%
# How often is each surcharge applied?

import pandas as pd
import matplotlib.pyplot as plt

# Make sure pickup_hour exists
df['pickup_hour'] = pd.to_datetime(df['tpep_pickup_datetime']).dt.hour

# Surcharge columns
surcharges = ['extra', 'mta_tax', 'congestion_surcharge', 'Airport_fee', 'improvement_surcharge', 'tolls_amount']

# Count surcharges by hour
hourly_surcharges = df[df[surcharges].gt(0).any(axis=1)].groupby('pickup_hour')[surcharges].sum()

# Plot surcharges by hour
hourly_surcharges.plot(kind='bar', stacked=True, figsize=(12,5))
plt.title('Surcharges by Hour')
plt.xlabel('Hour of Day')
plt.ylabel('Surcharge Amount')
plt.tight_layout()
plt.show()

# Count surcharges by top 10 pickup zones
top_zones = df['PULocationID'].value_counts().head(10).index
zone_surcharges = df[df['PULocationID'].isin(top_zones)].groupby('PULocationID')[surcharges].sum()

# Plot surcharges by pickup zone
zone_surcharges.plot(kind='bar', stacked=True, figsize=(12,5))
plt.title('Surcharges in Top 10 Pickup Zones')
plt.xlabel('Pickup Zone ID')
plt.ylabel('Surcharge Amount')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **4** Conclusion
# <font color = red>[15 marks]</font> <br>

# %% [markdown]
# ### **4.1** Final Insights and Recommendations
# <font color = red>[15 marks]</font> <br>
#
# Conclude your analyses here. Include all the outcomes you found based on the analysis.
#
# Based on the insights, frame a concluding story explaining suitable parameters such as location, time of the day, day of the week etc. to be kept in mind while devising a strategy to meet customer demand and optimise supply.

# %% [markdown]
# **4.1.1** <font color = red>[5 marks]</font> <br>
# Recommendations to optimize routing and dispatching based on demand patterns and operational inefficiencies

# %% [markdown]
# **4.1.2** <font color = red>[5 marks]</font> <br>
#
# Suggestions on strategically positioning cabs across different zones to make best use of insights uncovered by analysing trip trends across time, days and months.

# %% [markdown]
# **4.1.3** <font color = red>[5 marks]</font> <br>
# Propose data-driven adjustments to the pricing strategy to maximize revenue while maintaining competitive rates with other vendors.
